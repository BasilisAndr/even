# %% [markdown]
# Здесь:
#
# - вытащить самые частотные слова
# - сделать табличку русских заимствований

# %%
import os, re, pickle
from pprint import pprint
import numpy as np
import pandas as pd

# %%
def get_wdchains(corp):
    res = []
    for doc in corp:
        for sent in corp[doc]['text']:
            if 'ps' in sent:
                if len(sent['ps'])!=len(sent['mb']):
                    print(doc)
                    continue
                s = [(sent['mb'][i][0], sent['ge'][i][0], sent['ps'][i][0]) for i in range(len(sent['ps']))]
                res += s
    return res

with open('Sebjan.pickle', 'rb') as f:
    seb = pickle.load(f)
with open('Kamchatka.pickle', 'rb') as f:
    kam = pickle.load(f)

from collections import Counter
seb_wds = Counter(get_wdchains(seb))
kam_wds = Counter(get_wdchains(kam))
# Out:
# Kejmetinova_AA_headmistress_Yakutsk_310310_LZ.txt

# %%
seb_r = [(*x, seb_wds[x]) for x in seb_wds if x[1].endswith('.R')]
kam_r = [(*x, kam_wds[x]) for x in kam_wds if x[1].endswith('.R')]

seb_pd = pd.DataFrame({
        'word': list(map(lambda x: x[0], seb_r)),
        'transl': list(map(lambda x: x[1], seb_r)),
        'pos': list(map(lambda x: x[2], seb_r)),
        's_count': list(map(lambda x: x[3], seb_r))
    })

kam_pd = pd.DataFrame({
        'word': list(map(lambda x: x[0], kam_r)),
        'transl': list(map(lambda x: x[1], kam_r)),
        'pos': list(map(lambda x: x[2], kam_r)),
        'k_count': list(map(lambda x: x[3], kam_r))
    })

tog = pd.merge(seb_pd, kam_pd, on=['word', 'transl', 'pos'])

# %%
tog
# Out:
#          pos  s_count             transl       word  k_count
# 0          n        5         question.R     vopros        1
# 1          n       31             town.R      gorod       14
# 2        ptl        1             also.R       tože       87
# 3          n        7          teacher.R     učitel        7
# 4          n        1      October.loc.R   oktjabre        1
# 5          n        1            clock.R       časy        2
# 6          n        1             once.R        raz       10
# 7          n        5        tarpaulin.R    brezent        3
# 8          n        7             club.R       klub        3
# 9          n        2       steel.rope.R       trọs        1
# 10       num        1          two.acc.R       dvux        1
# 11         n        1           museum.R      muzej        6
# 12      pron        7              all.R        vse       20
# 13   postpos        1          without.R        bez        1
# 14       adj        2              any.R     ljuboj        1
# 15         n       26             trap.R     kapkan       11
# 16         n        1            glass.R     steklo        1
# 17         n        2             area.R  mestnost'        1
# 18         n        1             base.R       baza        2
# 19         n       16          tobacco.R      tabak        7
# 20         n        2        pensioner.R  pensioner        4
# 21         n        1           parcel.R    posylka        1
# 22       adv        5          further.R      dalše        3
# 23       adv        3          usually.R     obyčno        1
# 24         n        3         December.R    dekabr'        1
# 25         n       11  boarding.school.R   internat        5
# 26         n        1      grandfather.R    deduška        5
# 27         n        2               km.R   kilọmetr        2
# 28         n       10            flour.R     burduk        1
# 29         n       25          bicycle.R  velosiped       14
# ..       ...      ...                ...        ...      ...
# 279        n        1  reindeer.herder.R   olenovod        3
# 280        v        1              may.R      možno        1
# 281     pron        6            where.R        gde        8
# 282        v        1              can.R      možet        4
# 283  postpos        4               on.R         po        8
# 284     pron        1          3sg.acc.R        ego        2
# 285        n        6            youth.R   molodёž'        2
# 286        n        4            April.R      aprel        1
# 287      adv        2       in.Russian.R  po-russki        1
# 288        n        2         reindeer.R      olen'        1
# 289      ptl       11          that.is.R     značit        9
# 290     pron        1            where.R       kuda        3
# 291        n        1           cheese.R        syr        1
# 292        n        6           August.R     avgust        4
# 293        n        1             June.R      ijun'        3
# 294      adj        1             full.R     polnyj        2
# 295        n        2              vet.R    vetvrač        3
# 296      num        1     one.and.half.R    poltora        2
# 297        n        6           number.R      nomer        1
# 298        n        1         homework.R       urok        4
# 299        n       23             time.R     vremja        6
# 300        n        5           farmer.R     fermer        1
# 301   interj       66               so.R        tak       29
# 302        n        1           priest.R        pop        4
# 303        v        1           driver.R      šofer        1
# 304      adj        2              1pl.R         my        9
# 305      adv        1              now.R       sčas        4
# 306        n        7           office.R    kọntọra        1
# 307        n        1           carrot.R     morkov        1
# 308      adv        3           nearly.R      počti        1
#
# [309 rows x 5 columns]

# %%
print(sum(tog['s_count']))
print(sum(tog['k_count']))
# Out:
# 1837
# 2280
