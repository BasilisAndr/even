# %% [markdown]
# Здесь:
#
# - вытащить самые частотные слова
# - сделать табличку русских заимствований

# %%
import os, re, pickle
from pprint import pprint
import numpy as np
import pandas as pd

# %%
def get_wdchains(corp):
    res = []
    for doc in corp:
        for sent in corp[doc]['text']:
            if 'ps' in sent:
                if len(sent['ps'])!=len(sent['mb']):
                    print(doc)
                    continue
                s = [(sent['mb'][i][0], sent['ge'][i][0], sent['ps'][i][0]) for i in range(len(sent['ps']))]
                res += s
    return res

with open('Sebjan.pickle', 'rb') as f:
    seb = pickle.load(f)
with open('Kamchatka.pickle', 'rb') as f:
    kam = pickle.load(f)

from collections import Counter
seb_wds = Counter(get_wdchains(seb))
kam_wds = Counter(get_wdchains(kam))
# Out:
# Kejmetinova_AA_headmistress_Yakutsk_310310_LZ.txt

# %%
seb_r = [(*x, seb_wds[x]) for x in seb_wds if x[1].endswith('.R')]
kam_r = [(*x, kam_wds[x]) for x in kam_wds if x[1].endswith('.R')]

print(len(seb_r))
print(len(kam_r))

seb_pd = pd.DataFrame({
        'word': list(map(lambda x: x[0], seb_r)),
        'transl': list(map(lambda x: x[1], seb_r)),
        'pos': list(map(lambda x: x[2], seb_r)),
        's_count': list(map(lambda x: x[3], seb_r))
    })

kam_pd = pd.DataFrame({
        'word': list(map(lambda x: x[0], kam_r)),
        'transl': list(map(lambda x: x[1], kam_r)),
        'pos': list(map(lambda x: x[2], kam_r)),
        'k_count': list(map(lambda x: x[3], kam_r))
    })

tog = pd.merge(seb_pd, kam_pd, on=['word', 'transl', 'pos'], how='outer')
# Out:
# 1215
# 1381

# %%
tog.sort_values('k_count', ascending=False)
# Out:
#           pos  s_count                  transl           word  k_count
# 587         ?     36.0                   but.R            a.R    255.0
# 906      conj     26.0                   and.R              i    191.0
# 838       ptl     28.0                  here.R            vot     90.0
# 268       ptl      1.0                  also.R           tože     88.0
# 233       adv     69.0               already.R            uže     82.0
# 638      pron     19.0                  this.R            eto     70.0
# 388      conj     13.0                    or.R            ili     68.0
# 1916      adv      NaN                  then.R          potom     66.0
# 673      pron      4.0                   1sg.R             ja     39.0
# 740       ptl     19.0                  well.R             nu     39.0
# 870       adj     12.0                  that.R             to     38.0
# 96    postpos     16.0                    in.R              v     32.0
# 732    interj     65.0                    so.R            tak     29.0
# 216       adv      5.0                 still.R           ešče     28.0
# 290         n     46.0                school.R          škola     27.0
# 396      pron      9.0                   how.R            kak     27.0
# 951       ptl     33.0                   yes.R             da     27.0
# 397      pron      7.0                  what.R            čto     25.0
# 27        ptl     16.0                   ptl.R             že     25.0
# 879         n     33.0                  pear.R          gruša     24.0
# 87        adv      8.0                 there.R            tam     24.0
# 1577        n      NaN          fishing.camp.R        rybalka     24.0
# 2        pron      7.0                   all.R            vse     21.0
# 2243        n      NaN                   cow.R         korova     20.0
# 1612        n      NaN                 money.R          denga     18.0
# 1965        n      NaN           grandmother.R        babuška     17.0
# 1590        n      NaN                  yurt.R          jurta     17.0
# 2241        n      NaN               village.R           selo     17.0
# 1827      ptl      NaN              probably.R        naverno     16.0
# 1629  postpos      NaN                    at.R              u     16.0
# ...       ...      ...                     ...            ...      ...
# 1171        v      1.0                shaman.R          šaman      NaN
# 1174        n      2.0      three-year-olds?.R        tretjak      NaN
# 1175        n      1.0          fuel.station.R   benzokolonki      NaN
# 1176        n      1.0             (air)port.R           port      NaN
# 1178        n      1.0  marriage.arrangement.R     svatovstvo      NaN
# 1179        n      1.0        representative.R  predstavitel'      NaN
# 1180        n      2.0              armchair.R         kreslo      NaN
# 1181        n      2.0                  camp.R          lager      NaN
# 1183        n      1.0             protocoll.R       protokol      NaN
# 1187      adj      1.0                eighth.R        vos'moe      NaN
# 1188        n      1.0                 spear.R         kop'jё      NaN
# 1189      adj      1.0                female.R       ženskaja      NaN
# 1190        n      1.0                 flock.R          staja      NaN
# 1191      adj      1.0              nineties.R    devjanostyx      NaN
# 1192        v      1.0                joined.R  podključilsja      NaN
# 1193        n      1.0                tumour.R        opuxol'      NaN
# 1194        n      2.0              contract.R        dogovor      NaN
# 1195      adj      1.0                 small.R          maloe      NaN
# 1198        n      1.0              relative.R    rodstvennik      NaN
# 1199      adj      1.0              in.cubes.R       kuskovoj      NaN
# 1200        n      5.0                 radio.R         racija      NaN
# 1201        n      7.0            snowmobile.R          buran      NaN
# 1202        n      1.0              she.bear.R     medveditsa      NaN
# 1204      adj      1.0                 steep.R         krụtọj      NaN
# 1206        n      2.0  reindeer.herders.gen.R     olenevodov      NaN
# 1208        n      1.0     teachers'.college.R    pedučilišče      NaN
# 1209      num      4.0                 fifty.R    pjatdesjat'      NaN
# 1211        n      1.0            technician.R    texrabotnik      NaN
# 1212        n      1.0          instructions.R          nakaz      NaN
# 1214        n      1.0                  bead.R           busy      NaN
#
# [2287 rows x 5 columns]

# %%
print(sum(tog['s_count']))
print(sum(tog['k_count']))
# Out:
# 1831
# 2294

# %%
len(tog.loc[tog['s_count']>0].loc[tog['pos']=='n'])
# Out:
# 793

# %%
seb_y = [(*x, seb_wds[x]) for x in seb_wds if x[1].endswith('.Y')]
kam_y = [(*x, kam_wds[x]) for x in kam_wds if x[1].endswith('.Y')]

sum(map(lambda x: x[3], seb_y))
# Out:
# 3746

# %%
with open('Kamchatka_morphemes.pickle', 'rb') as f:
    kam_m = pickle.load(f)
with open('Sebjan_morphemes.pickle', 'rb') as f:
    seb_m = pickle.load(f)

seb_y = [x for x in seb_m if x[1].endswith('.Y')]
kam_y = [x for x in kam_m if x[1].endswith('.Y')]

print(len(seb_y))
# Out:
# 619

# %%
seb_y
# Out:
# [('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', '3pl.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', '3pl.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', '3pl.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('BAt', 'neg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('lEːx', 'prop.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('par', 'dat.1sg.Y', 'n'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dan', 'vr.cvb.Y', '?'),
#  ('jEktEːk', 'nec.Y', '?'),
#  ('GIn', 'pred.2sg.Y', '?'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('BAt', 'neg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('An', 'pf.cvb.Y', '?'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('BAt', 'neg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('lEːx', 'prop.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('EllEr', 'prs.ptc.Y', 'v'),
#  ('EllEr', 'prs.ptc.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', 'poss.3pl.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('jEkkE', 'futpt.dat.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('jEkkE', 'futpt.dat.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('BIt', 'pf.ptcp.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('EllEr', 'prs.ptc.Y', 'v'),
#  ('EllEr', 'prs.ptc.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('EbIt', 'prs.1pl.Y', 'v'),
#  ('EllEr', 'prs.ptc.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jaktara', 'fut.3pl.Y', 'v'),
#  ('jekterin', 'hyp.3pl.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('InEn', 'ins.Y', 'adj'),
#  ('IEn', 'futpt.acc.3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', '?'),
#  ('IEn', 'futpt.acc.3sg.Y', 'v'),
#  ('EbIn', 'prs.1sg.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('BIt', '1pl.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('t', 'caus.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('jEktErIn', 'futpt.acc.3pl.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', 'poss.3pl.Y', 'v'),
#  ('jEkkE', 'futpt.dat.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIn', 'pred.1sg.Y', 'v'),
#  ('EbIn', 'prs.1sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jEːkkIn', 'hyp.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Iŋ', 'poss.2sg.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('IEn', 'futpt.acc.3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('jEktErIn', 'futpt.acc.3pl.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIt', 'poss.1pl.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIt', 'poss.1pl.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', '3pl.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('DʒIt', 'agnr.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jeːgin', 'hyp.3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GA', 'dat.Y', 'n'),
#  ('(t)tAn', 'abl.Y', 'n'),
#  ('(t)tAn', 'abl.Y', 'n'),
#  ('(I)nAn', 'ins.Y', '?'),
#  ('GA', 'dat.Y', 'n'),
#  ('GA', 'dat.Y', 'n'),
#  ('LIːn', 'com.Y', '?'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('LAr', 'pl.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('LArIn', 'acc.3pl.Y', 'v'),
#  ('LAr', 'pl.Y', 'n'),
#  ('(t)In', 'gen.Y', 'n'),
#  ('GA', 'dat.Y', 'n'),
#  ('GA', 'dat.Y', '?'),
#  ('GA', 'dat.Y', 'n'),
#  ('GA', 'dat.Y', 'n'),
#  ('GA', 'dat.Y', 'n'),
#  ('IA', 'fut.3sg.Y', 'v'),
#  ('BIt', '1pl.Y', 'ptl'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('InEn', 'ins.Y', 'adj'),
#  ('jEkkE', 'futpt.dat.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIt', 'poss.1pl.Y', 'v'),
#  ('EllEr', 'prs.3pl.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('BAt', 'neg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('BAtAx', 'pstpt.neg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('BAt', 'neg.Y', 'v'),
#  ('BAppIn', 'prs.1sg.neg.Y', 'v'),
#  ('jEːkpIn', 'hyp.1sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('EllEr', 'prs.3pl.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('BIt', '1pl.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', 'poss.3pl.Y', 'v'),
#  ('EbIt', 'prs.1pl.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('InEn', 'ins.Y', 'n'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jEktErIn', 'futpt.acc.3pl.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIt', 'poss.1pl.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('s', 'rec.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', '?'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIt', '1pl.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIt', '1pl.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Iŋ', 'poss.2sg.Y', 'v'),
#  ('DʒIt', 'agnr.Y', 'n'),
#  ('DʒIt', 'agnr.Y', 'n'),
#  ('dan', 'vr.cvb.Y', 'adv'),
#  ('DʒIt', 'agnr.Y', 'n'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('EbIn', 'prs.1sg.Y', 'v'),
#  ('LEn', 'vr.Y', 'v'),
#  ('t', 'caus.Y', 'v'),
#  ('DʒIt', 'agnr.Y', 'n'),
#  ('Ar', 'prs.ptcp.Y', '?'),
#  ('LEn', 'vr.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('IEn', 'futpt.acc.3sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('EbIn', 'prs.1sg.Y', 'v'),
#  ('EbIn', 'prs.1sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIt', 'pred.2pl.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIt', 'pred.2pl.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', '?'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', 'poss.3pl.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', 'poss.3pl.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIt', 'poss.1pl.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('diː', 'emph.Y', 'ptl'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIn', 'pred.1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'ptl'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', '?'),
#  ('E', '3sg.Y', '?'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'ptl'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEːkpIn', 'hyp.1sg.Y', 'v'),
#  ('An', 'pf.cvb.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('BAt', 'neg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('BIt', 'poss.1pl.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('ta', 'part.Y', '?'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Iŋ', 'poss.2sg.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('EgIn', 'prs.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('GIn', 'pred.2sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIt', '1pl.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('EbIn', 'prs.1sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Is', 'ord.Y', '?'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('s', 'rec.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('jEkkE', 'futpt.dat.Y', 'v'),
#  ('jEkkE', 'futpt.dat.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('BIn', 'pred.1sg.Y', 'v'),
#  ('IEn', 'futpt.acc.3sg.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEktEːk', 'nec.Y', 'v'),
#  ('jEkkE', 'futpt.dat.Y', 'v'),
#  ('jEktEːk', 'nec.Y', '?'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Ar', 'prs.ptcp.Y', '?'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', 'poss.3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('LArA', '3pl.Y', 'v'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('Is', 'ord.Y', 'num'),
#  ('dEg', 'assert.Y', 'v'),
#  ('BIt', 'poss.1pl.Y', 'v'),
#  ('diː', 'emph.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', '?'),
#  ('dEg', 'assert.Y', 'v'),
#  ('E', '3sg.Y', 'v'),
#  ('Ar', 'prs.ptcp.Y', 'v'),
#  ('dEg', 'assert.Y', 'v'),
#  ('Im', '1sg.Y', 'v'),
#  ('diː', 'emph.Y', 'v')]

# %%
len(kam_y)
# Out:
# 2

# %%
print(len(get_wdchains(seb)))
len(get_wdchains(kam))
# Out:
# Kejmetinova_AA_headmistress_Yakutsk_310310_LZ.txt
# 49803
# 32778

# %%
3746/49803
# Out:
# 0.07521635242856856

# %%
2280/32778
# Out:
# 0.06955885044847153
