# %% [markdown]
# Здесь:
#
# - вытащить самые частотные слова
# - сделать табличку русских заимствований

# %%
import os, re, pickle
from pprint import pprint
import numpy as np
import pandas as pd

# %%
def get_wdchains(corp):
    res = []
    for doc in corp:
        for sent in corp[doc]['text']:
            if 'ps' in sent:
                if len(sent['ps'])!=len(sent['mb']):
                    print(doc)
                    continue
                s = [(sent['mb'][i][0], sent['ge'][i][0], sent['ps'][i][0]) for i in range(len(sent['ps']))]
                res += s
    return res

with open('Sebjan.pickle', 'rb') as f:
    seb = pickle.load(f)
with open('Kamchatka.pickle', 'rb') as f:
    kam = pickle.load(f)

from collections import Counter
seb_wds = Counter(get_wdchains(seb))
kam_wds = Counter(get_wdchains(kam))
# Out:
# Kejmetinova_AA_headmistress_Yakutsk_310310_LZ.txt

# %%
seb_r = [(*x, seb_wds[x]) for x in seb_wds if x[1].endswith('.R')]
kam_r = [(*x, kam_wds[x]) for x in kam_wds if x[1].endswith('.R')]

seb_pd = pd.DataFrame({
        'word': list(map(lambda x: x[0], seb_r)),
        'transl': list(map(lambda x: x[1], seb_r)),
        'pos': list(map(lambda x: x[2], seb_r)),
        's_count': list(map(lambda x: x[3], seb_r))
    })

kam_pd = pd.DataFrame({
        'word': list(map(lambda x: x[0], kam_r)),
        'transl': list(map(lambda x: x[1], kam_r)),
        'pos': list(map(lambda x: x[2], kam_r)),
        'k_count': list(map(lambda x: x[3], kam_r))
    })

tog = pd.merge(seb_pd, kam_pd, on=['word', 'transl', 'pos'])

# %%
tog
# Out:
#          pos  s_count             transl       word  k_count
# 0          n        5         question.R     vopros        1
# 1          n       31             town.R      gorod       14
# 2        ptl        1             also.R       tože       87
# 3          n        7          teacher.R     učitel        7
# 4          n        1      October.loc.R   oktjabre        1
# 5          n        1            clock.R       časy        2
# 6          n        1             once.R        raz       10
# 7          n        5        tarpaulin.R    brezent        3
# 8          n        7             club.R       klub        3
# 9          n        2       steel.rope.R       trọs        1
# 10       num        1          two.acc.R       dvux        1
# 11         n        1           museum.R      muzej        6
# 12      pron        7              all.R        vse       20
# 13   postpos        1          without.R        bez        1
# 14       adj        2              any.R     ljuboj        1
# 15         n       26             trap.R     kapkan       11
# 16         n        1            glass.R     steklo        1
# 17         n        2             area.R  mestnost'        1
# 18         n        1             base.R       baza        2
# 19         n       16          tobacco.R      tabak        7
# 20         n        2        pensioner.R  pensioner        4
# 21         n        1           parcel.R    posylka        1
# 22       adv        5          further.R      dalše        3
# 23       adv        3          usually.R     obyčno        1
# 24         n        3         December.R    dekabr'        1
# 25         n       11  boarding.school.R   internat        5
# 26         n        1      grandfather.R    deduška        5
# 27         n        2               km.R   kilọmetr        2
# 28         n       10            flour.R     burduk        1
# 29         n       25          bicycle.R  velosiped       14
# ..       ...      ...                ...        ...      ...
# 279        n        1  reindeer.herder.R   olenovod        3
# 280        v        1              may.R      možno        1
# 281     pron        6            where.R        gde        8
# 282        v        1              can.R      možet        4
# 283  postpos        4               on.R         po        8
# 284     pron        1          3sg.acc.R        ego        2
# 285        n        6            youth.R   molodёž'        2
# 286        n        4            April.R      aprel        1
# 287      adv        2       in.Russian.R  po-russki        1
# 288        n        2         reindeer.R      olen'        1
# 289      ptl       11          that.is.R     značit        9
# 290     pron        1            where.R       kuda        3
# 291        n        1           cheese.R        syr        1
# 292        n        6           August.R     avgust        4
# 293        n        1             June.R      ijun'        3
# 294      adj        1             full.R     polnyj        2
# 295        n        2              vet.R    vetvrač        3
# 296      num        1     one.and.half.R    poltora        2
# 297        n        6           number.R      nomer        1
# 298        n        1         homework.R       urok        4
# 299        n       23             time.R     vremja        6
# 300        n        5           farmer.R     fermer        1
# 301   interj       66               so.R        tak       29
# 302        n        1           priest.R        pop        4
# 303        v        1           driver.R      šofer        1
# 304      adj        2              1pl.R         my        9
# 305      adv        1              now.R       sčas        4
# 306        n        7           office.R    kọntọra        1
# 307        n        1           carrot.R     morkov        1
# 308      adv        3           nearly.R      počti        1
#
# [309 rows x 5 columns]

# %%
print(sum(tog['s_count']))
print(sum(tog['k_count']))
# Out:
# 1837
# 2280

# %%
seb_y = [(*x, seb_wds[x]) for x in seb_wds if x[1].endswith('.Y')]
kam_y = [(*x, kam_wds[x]) for x in kam_wds if x[1].endswith('.Y')]

sum(map(lambda x: x[3], seb_y))
# Out:
# 3746

# %%
with open('Kamchatka_morphemes.pickle', 'rb') as f:
    kam_m = pickle.load(f)
with open('Sebjan_morphemes.pickle', 'rb') as f:
    seb_m = pickle.load(f)

seb_y = [x for x in seb_m if x[1].endswith('.Y')]
kam_y = [x for x in kam_m if x[1].endswith('.Y')]

print(len(seb_y))
# Out:
# 619

# %%
seb_y
# Out:
# [('koːrček', 'whipped.cream.Y', '?', 4),
#  ('hüːrebet', 'incredible.Y', 'adv', 1),
#  ('is', 'inside.Y', 'n', 1),
#  ('ühü', 'hsy.Y', 'ptl', 52),
#  ('ebeter', 'or.Y', 'conj', 16),
#  ('küːs', 'force.Y', '?', 1),
#  ('aras', 'various.Y', 'adv', 1),
#  ('hakaːstaː', 'order.Y', 'v', 1),
#  ('daγanï', 'even.Y', 'ptl', 23),
#  ('es', 'no.Y', 'interj', 9),
#  ('kọnọhọ', 'guest.Y', 'v', 1),
#  ('dien', 'saying.Y', 'v', 13),
#  ('ọγọlọr', 'children.Y', 'n', 1),
#  ('bastaː', 'be.first.Y', 'v', 1),
#  ('činčij', 'study.Y', 'v', 1),
#  ('anï', 'now.Y', 'adv', 30),
#  ('adʒas', 'completely.Y', 'adv', 4),
#  ('emten', 'cure.oneself.Y', 'v', 2),
#  ('erej', 'trouble.Y', 'n', 13),
#  ('ajụkaja', 'suddenly.Y', 'interj', 11),
#  ('xahïat', 'newspaper.Y', 'n', 5),
#  ('bụ', 'that.Y', '?', 1),
#  ('χaːjïː', 'prison.Y', 'n', 1),
#  ('ńụːčalïː', 'in.Russian.Y', 'adv', 1),
#  ('ụhụl', 'take.off.Y', 'v', 2),
#  ('erejdeːk', 'trouble.prop.Y', 'adj', 2),
#  ('kömölös', 'help.Y', 'v', 4),
#  ('süːs', 'hundred.Y', 'num', 2),
#  ('sajdï', 'develop.Y', 'v', 1),
#  ('sïhïannas', 'have.relations.Y', 'v', 1),
#  ('söbüleː', 'agree.Y', 'v', 1),
#  ('naːr', 'always.Y', 'adv', 6),
#  ('kuot', 'run.away.Y', 'v', 1),
#  ('mannïk', 'prox.qual.Y', 'adv', 1),
#  ('ọnnụ', 'place.Y', 'rel.n', 6),
#  ('atịlaː', 'sell.Y', 'v', 1),
#  ('ötör', 'recently.Y', 'adv', 2),
#  ('kïrahaː', 'powder.snow.Y', 'n', 1),
#  ('xajïhar', 'skis.Y', 'n', 3),
#  ('mọsta', 'floor.Y', 'n', 3),
#  ('kịajbat', 'not.able.Y', 'v', 1),
#  ('taŋara', 'god.Y', 'n', 1),
#  ('emteː', 'treat.Y', 'v', 6),
#  ('kïrïnaːs', 'ermine.Y', 'n', 2),
#  ('hajda', 'nail.Y', 'v', 1),
#  ('uonna', 'and.Y', 'conj', 4),
#  ('birde', 'only.Y', 'adv', 1),
#  ('seleːnčik', 'vest.Y', 'n', 2),
#  ('sïːha', 'mistake.Y', 'n', 1),
#  ('belemneː', 'make.ready.Y', 'v', 2),
#  ('buruj', 'guilt.Y', 'n', 1),
#  ('tus', 'about.Y', 'postpos', 7),
#  ('ikkis', 'second.Y', 'num', 1),
#  ('ọl', 'that.Y', 'pron', 11),
#  ('bilbeppin', "I.don't.know.Y", 'v', 1),
#  ('mụnńak', 'meeting.Y', 'n', 1),
#  ('χaːj', 'lock.up.Y', 'v', 1),
#  ('öttüten', 'from.the.side.Y', 'postpos', 1),
#  ('tïːhïnča', 'thousand.Y', 'num', 19),
#  ('saxa', 'Sakha.Y', 'n', 1),
#  ('očos', 'be.stubborn.Y', 'v', 1),
#  ('üöske', 'raise.Y', 'v', 1),
#  ('baγar', 'perhaps.Y', 'adv', 13),
#  ('dʒaːm', 'post.Y', 'n', 3),
#  ('ülüj', 'freeze.Y', 'v', 1),
#  ('baγajï', 'very.Y', 'adv', 18),
#  ('họlkọbaj', 'ruble.Y', 'n', 1),
#  ('oloχtoːχ', 'local.Y', 'n', 1),
#  ('diːr', 'says.prs.3sg.Y', 'v', 1),
#  ('sotoru', 'soon.Y', 'adv', 4),
#  ('tölö', 'pay.Y', 'v', 1),
#  ('ieden', 'misfortune.Y', 'n', 7),
#  ('hette', 'seven.Y', 'num', 3),
#  ('ihin', 'for.Y', '?', 2),
#  ('kuruk', 'always.Y', '?', 5),
#  ('naːdïj', 'need.Y', 'v', 1),
#  ('kụmaga', 'paper.R.Y', 'n', 1),
#  ('ọtụt', 'thirty.Y', 'num', 2),
#  ('biːr', 'one.Y', 'num', 3),
#  ('ol_gïnan_baran', 'but.Y', 'conj', 3),
#  ('tik', 'sew.Y', 'v', 1),
#  ('eppiettes', 'answer.many.times.Y', 'v', 1),
#  ('alγas', 'error.Y', 'n', 1),
#  ('üldʒü', 'immediately.Y', 'adv', 9),
#  ('tụh', 'salt.Y', '?', 1),
#  ('baːj', 'rich.Y', 'n', 5),
#  ('oččoγuna', 'then.Y', 'adv', 3),
#  ('araːhịnaj', 'various.Y', 'adv', 10),
#  ('miːn', 'soup.Y', 'n', 1),
#  ('otton', 'dp.Y', '?', 29),
#  ('üörekteːk', 'education.prop.Y', 'adj', 3),
#  ('dọγọr', 'friend.Y', 'n', 2),
#  ('tuhunan', 'about.Y', 'postpos', 1),
#  ('ühü', 'say.Y', '?', 3),
#  ('haγana', 'time.loc.Y', '?', 1),
#  ('aːjï', 'every.Y', 'adv', 6),
#  ('saŋadʒïl', 'New.Year.Y', 'n', 1),
#  ('törüt', 'completely.Y', 'adv', 2),
#  ('tïhïːnča', 'thousand.Y', '?', 1),
#  ('bïlïrgï', 'previous.Y', 'adj', 7),
#  ('hiep', 'pocket.Y', 'n', 2),
#  ('anaːn', 'on.purpose.Y', '?', 4),
#  ('xọs', 'room.Y', 'n', 1),
#  ('keliŋ', 'come.imp.2pl.Y', 'v', 1),
#  ('bej', 'self.Y', 'pron', 136),
#  ('ọl_aːta', 'that.means.Y', 'conj', 1),
#  ('tugu', 'what.acc.Y', 'pron', 1),
#  ('araŋas', 'store.room.Y', 'n', 11),
#  ('aːn_bastaːn', 'at.first.Y', 'adv', 2),
#  ('töhö', 'how.much.Y', 'pron', 2),
#  ('ete', 'be.pst.3sg.Y', 'v', 6),
#  ('sọγụs', 'relatively.Y', 'adv', 4),
#  ('tus_tuhunan', 'separately.Y', 'adv', 1),
#  ('ültü', 'ints.Y', 'adv', 1),
#  ('hataːn', 'not.be.able.Y', 'v', 5),
#  ('bọlaktara', 'aux.assert.3pl.Y', 'v', 1),
#  ('ụọnna', 'and.Y', '?', 6),
#  ('be', 'ptl.Y', 'ptl', 4),
#  ('kïlaːhï', 'grade.acc.Y', 'n', 1),
#  ('sin', 'a.bit.Y', 'ptl', 26),
#  ('biehon', 'fifty.Y', 'num', 2),
#  ('hibienneː', 'appear(of.ghost).Y', 'v', 1),
#  ('bïlaːt', 'kerchief.Y', 'n', 2),
#  ('aːspït', 'past.Y', 'adj', 1),
#  ('kiergemseχ', 'dandy.Y', 'adj', 1),
#  ('ebet', 'emph.Y', 'ptl', 1),
#  ('kïallïbat', 'not.be.able.Y', 'v', 1),
#  ('dʒiŋneːk', 'truly.Y', 'adv', 4),
#  ('čaraːs', 'thin.Y', 'adj', 1),
#  ('tebin', 'kick.Y', 'v', 1),
#  ('araj', 'suddenly.Y', 'adv', 9),
#  ('uspejdaː', 'manage.Y', 'v', 1),
#  ('öj', 'mind.Y', 'n', 2),
#  ('öjdöː', 'remember.Y', 'v', 6),
#  ('suoχtaːχ', 'neg.nec.Y', 'ptl', 1),
#  ('ïnïrïk', 'terribly.Y', 'adv', 7),
#  ('emčit', 'doctor.Y', '?', 1),
#  ('heŋeːr', 'be.very.interested.Y', 'v', 1),
#  ('bụkatïn', 'completely.Y', 'adv', 19),
#  ('erej', 'trouble.Y', 'v', 1),
#  ('este', 'blow.up.Y', 'v', 3),
#  ('bütünnüː', 'entirely.Y', '?', 99),
#  ('ebite', 'aux.pstptc.poss.3sg.Y', 'ptl', 1),
#  ('ičči', 'spirit.Y', 'n', 2),
#  ('ọγọ', 'child.Y', 'n', 1),
#  ('ọtụː', 'fire.Y', 'n', 25),
#  ('orex', 'studies.Y', 'n', 1),
#  ('bastaːn', 'at.first.Y', 'adv', 8),
#  ('töttörü', 'back.Y', 'adv', 3),
#  ('tụtta', 'use.Y', 'v', 1),
#  ('haγalaː', 'begin.Y', 'v', 4),
#  ('üle', 'work.Y', 'n', 10),
#  ('en', '2sg.Y', 'pron', 1),
#  ('tördüs', 'fourth.Y', 'num', 2),
#  ('kurojek', 'fugitive.Y', 'n', 1),
#  ('olbuor', 'fence.Y', 'n', 3),
#  ('ürüje', 'stream.Y', 'n', 1),
#  ('hene', 'despise.Y', 'v', 2),
#  ('kiːs', 'sable.Y', 'n', 5),
#  ('hïarga', 'sled.Y', 'n', 27),
#  ('bïlïrïn', 'last.year.Y', 'adv', 1),
#  ('hetteuon', 'seventy.Y', 'num', 1),
#  ('ataːr', 'see.off.Y', 'v', 1),
#  ('süːrbe', 'twenty.Y', 'num', 3),
#  ('emie', 'also.Y', 'adv', 310),
#  ('küːle', 'inner.porch.Y', 'n', 1),
#  ('uluːs', 'district.Y', 'n', 10),
#  ('baγajị', 'very.Y', 'n', 2),
#  ('ajuka', 'suddenly.Y', '?', 2),
#  ('bütej', 'enclosed.Y', '?', 1),
#  ('xata_kimneːger', 'more.or.less.Y', 'adv', 1),
#  ('hïldʒar', 'go.prs.3sg.Y', 'v', 1),
#  ('bụltaː', 'hunt.Y', 'v', 9),
#  ('ụsta', 'length.Y', 'rel.n', 1),
#  ('ebeheːt', 'without.fail.R.Y', 'ptl', 6),
#  ('kọnụk', '24.hour.period.Y', 'n', 2),
#  ('axsïs', 'eighth.Y', 'num', 4),
#  ('heren', 'be.careful.Y', 'v', 1),
#  ('ụlarïj', 'change.Y', 'v', 1),
#  ('taːs', 'rock.Y', 'n', 1),
#  ('tahaγas', 'load.Y', 'n', 1),
#  ('bert', 'super.Y', 'adv', 1),
#  ('bussa', 'even.more.Y', 'adv', 9),
#  ('inne', 'needle.Y', 'n', 1),
#  ('ọmụk', 'foreigner.Y', 'n', 1),
#  ('erde', 'early.Y', 'adv', 5),
#  ('nehiliek', 'nasleg.Y', 'n', 3),
#  ('meːne', 'simply.Y', 'adv', 29),
#  ('haγalaːn', 'begin.cvb.Y', 'v', 1),
#  ('emiske', 'suddenly.Y', 'adv', 12),
#  ('xọmụj', 'gather.Y', 'v', 16),
#  ('ọntọn', 'then.Y', 'adv', 1),
#  ('üöremmekkin', "you.don't.study.Y", 'v', 1),
#  ('kuruːssa', 'chicken.Y', 'n', 6),
#  ('bọrụọsta', 'simple.Y', '?', 3),
#  ('ajịlga', 'nature.Y', 'n', 1),
#  ('aldʒarxaj', 'misfortune.Y', 'n', 2),
#  ('üören', 'study.Y', 'v', 5),
#  ('aːnńa', 'good.Y', 'adj', 1),
#  ('altauon', 'sixty.Y', 'num', 1),
#  ('ajụka', 'suddenly.Y', 'interj', 6),
#  ('kuːs', 'force.Y', 'n', 3),
#  ('hụlụzbala', 'serve.Y', 'v', 1),
#  ('höbüj', 'OK.q.Y', 'ptl', 2),
#  ('iŋin', 'etc.Y', 'ptl', 195),
#  ('siːkej', 'raw.Y', 'adj', 1),
#  ('saγana', 'time.loc.Y', 'adv', 9),
#  ('ọnọn', 'therefore.Y', '?', 1),
#  ('haːrat', 'distract.Y', 'v', 1),
#  ('ụsta', 'throughout.Y', 'postpos', 1),
#  ('settis', 'seventh.Y', 'num', 13),
#  ('battat', 'suffer.from.nightmares.Y', 'v', 1),
#  ('ọnụs', 'tenth.Y', 'num', 2),
#  ('bil', 'know.Y', 'v', 3),
#  ('suːlaː', 'fold.Y', 'v', 1),
#  ('dụha', 'soul.R.Y', 'n', 3),
#  ('söpkö', 'correctly.Y', 'adv', 1),
#  ('dʒeː', 'well.Y', '?', 1),
#  ('χarabïllaː', 'guard.Y', 'v', 2),
#  ('büt', 'end.Y', '?', 1),
#  ('buolla', 'dp.Y', '?', 7),
#  ('kara', 'black.Y', 'adj', 1),
#  ('haxalïː', 'in.Sakha.Y', 'adv', 1),
#  ('tụːra', 'throughout.Y', 'postpos', 1),
#  ('kötöl', 'following.sled.Y', 'n', 3),
#  ('suttaː', 'prosecute.Y', 'v', 1),
#  ('tuoxta', 'nothing.Y', 'pron', 1),
#  ('če', 'ptl.Y', 'ptl', 18),
#  ('buolbatax', 'aux.neg.pst.ptc.Y', 'v', 1),
#  ('ọhọk', 'stove.Y', 'n', 33),
#  ('ini', 'probably.Y', 'ptl', 2),
#  ('hịsta', 'get.infected.Y', 'v', 2),
#  ('xaja', 'what.Y', '?', 1),
#  ('mehej', 'interfere.Y', 'v', 2),
#  ('tutun', 'use.Y', 'v', 1),
#  ('buol', 'aux.Y', 'v', 85),
#  ('sahïl', 'fox.Y', 'n', 1),
#  ('taba', 'reindeer.Y', 'n', 5),
#  ('ụhụlụn', 'take.off.pass.Y', 'v', 1),
#  ('össö', 'still.Y', 'adv', 28),
#  ('dʒiŋ', 'very.Y', 'adv', 62),
#  ('bụlat', 'headscarf.Y', '?', 1),
#  ('xajïːr', 'do.what.prs.3sg.Y', 'v', 1),
#  ('baγar', 'wish.Y', '?', 8),
#  ('dʒahaj', 'manage.Y', 'v', 1),
#  ('xọtụ', 'North.Y', '?', 1),
#  ('ajannaː', 'journey.Y', 'v', 12),
#  ('kịahị', 'hobble.Y', 'v', 1),
#  ('hụllaː', 'wrap.Y', 'v', 3),
#  ('söp', 'OK.Y', 'ptl', 21),
#  ('bïlaːs', 'power.Y', 'n', 10),
#  ('beleχ', 'present.Y', 'n', 1),
#  ('tuoχ', 'what.Y', 'pron', 1),
#  ('halgïn', 'air.Y', 'n', 2),
#  ('onnuk', 'dist.qual.Y', 'adv', 3),
#  ('ụdaγan', 'female.shaman.Y', 'v', 1),
#  ('alta', 'six.Y', 'num', 5),
#  ('sïllaːk', 'the.year.Y', 'n', 1),
#  ('bọrụọstọj', 'simple.Y', 'adj', 2),
#  ('ïrastaː', 'clean.Y', 'v', 2),
#  ('beder', 'lynx.Y', 'n', 1),
#  ('χajdaχ', 'how.Y', 'pron', 1),
#  ('tụspa', 'separately.Y', 'adv', 29),
#  ('bukatïn', 'completely.Y', '?', 1),
#  ('tọlọː', 'fill.up.Y', 'v', 1),
#  ('xọlọbụr', 'for.example.Y', 'adv', 7),
#  ('dʒiŋinen', 'in.truth.Y', 'adv', 4),
#  ('hatar', 'xotja.by.Y', 'ptl', 1),
#  ('tọxsụs', 'ninth.Y', 'num', 1),
#  ('haba', 'cover.cvb.Y', 'v', 1),
#  ('bụlta', 'hunt.Y', 'v', 1),
#  ('üleleː', 'work.Y', 'v', 16),
#  ('xamnas', 'salary.Y', 'n', 1),
#  ('ọlọk', 'sitting.Y', '?', 2),
#  ('toγuhuon', 'ninety.Y', 'num', 1),
#  ('belem', 'ready.Y', 'adj', 2),
#  ('hatanar', 'necessary.Y', 'ptl', 3),
#  ('ewenni', 'Ewen.Y', 'adv', 2),
#  ('bụlkaːs', 'mixture.Y', 'n', 1),
#  ('tụŋtaŋ', 'do.badly.Y', 'ptl', 1),
#  ('bili', 'that.one.Y', 'pron', 1),
#  ('üksü', 'mostly.Y', 'adv', 4),
#  ('tọkta', 'ptl.Y', 'ptl', 1),
#  ('sömölüöt', 'airplane.Y', 'n', 1),
#  ('bu', 'that.Y', 'pron', 4),
#  ('sien', 'grandchild.Y', 'n', 1),
#  ('aγïs', 'eight.Y', 'num', 1),
#  ('ọttọn', 'dp.Y', 'ptl', 174),
#  ('ọl_ihin', 'therefore.Y', 'conj', 33),
#  ('himbiːr', 'all.the.same.Y', 'adv', 27),
#  ('dʒühün', 'appearance.Y', 'n', 1),
#  ('uruhujda', 'draw.Y', 'v', 5),
#  ('xata', 'thank.god.Y', 'ptl', 9),
#  ('suptu', 'during.Y', 'postpos', 1),
#  ('hïllaːkka', 'in.the.year.Y', 'adv', 7),
#  ('ọlọk', 'sitting.Y', 'n', 1),
#  ('ọrtọ', 'middle.Y', 'rel.n', 1),
#  ('saγalan', 'begin.Y', 'v', 1),
#  ('ụlam', 'gradually.Y', 'adv', 7),
#  ('ụọpsajịnan', 'in.general.Y', '?', 2),
#  ('ajmak', 'relatives.Y', 'n', 5),
#  ('hopxuos', 'soviet.farm.Y', 'n', 1),
#  ('čụgaha', 'come.closer.Y', 'v', 5),
#  ('ụčụtal', 'teacher.Y', 'n', 3),
#  ('algaː', 'say.blessing.Y', 'v', 1),
#  ('küörčex', 'whipped.cream.Y', 'n', 3),
#  ('balịhïańa', 'situation.Y', 'n', 1),
#  ('seriː', 'war.Y', 'n', 5),
#  ('buollar', 'dp.Y', 'ptl', 102),
#  ('hatakka', 'in.addition.Y', 'ptl', 2),
#  ('sügün', 'quietly.Y', 'adv', 1),
#  ('bịːs', 'crack.Y', 'rel.n', 1),
#  ('ụlụːs', 'district.Y', 'n', 1),
#  ('orduk', 'better.Y', 'adv', 1),
#  ('buoluo', 'probably.Y', 'ptl', 5),
#  ('bịhịt', 'weir.Y', 'n', 5),
#  ('kọs', 'second.Y', 'n', 4),
#  ('tünnük', 'window.Y', 'n', 5),
#  ('uonikki', 'twelve.Y', 'num', 3),
#  ('bịhịt', 'plotina.Y', 'n', 1),
#  ('kọmụj', 'gather.Y', 'v', 4),
#  ('axsịn', 'every.Y', 'quant', 1),
#  ('kọmụrgan', 'collarbone.Y', 'n', 2),
#  ('iti', 'this.Y', 'pron', 1),
#  ('arïj', 'a.bit.Y', 'adv', 1),
#  ('battaː', 'fit.in.Y', 'v', 1),
#  ('keriete', 'as.if.Y', 'adv', 1),
#  ('tïnnak', 'alive.Y', 'adv', 1),
#  ('ịksahịt', 'hurrying?.Y', 'n', 1),
#  ('nehiːle', 'barely.Y', 'adv', 8),
#  ('ajụːja', 'interj.Y', 'interj', 4),
#  ('nahaː', 'very.Y', 'adv', 85),
#  ('tụs', 'redup.Y', 'ptl', 4),
#  ('oskuolaγa', 'school.dat.Y', 'n', 2),
#  ('axsaːn', 'counting.Y', 'v', 1),
#  ('gïna', 'do.ipf.cvb.Y', 'v', 2),
#  ('toγus', 'nine.Y', 'num', 5),
#  ('kịrịn', 'drag.several.times.Y', 'v', 1),
#  ('üöreχ', 'study.Y', 'n', 1),
#  ('diːbin', 'say.prs.1sg.Y', 'v', 1),
#  ('xataːhïn', 'bolt.Y', 'n', 2),
#  ('min', '1sg.Y', 'pron', 1),
#  ('uon', 'ten.Y', 'num', 7),
#  ('dʒe', 'well.Y', 'ptl', 371),
#  ('kuorat', 'town.Y', 'n', 1),
#  ('dïlï', 'until.Y', 'postpos', 15),
#  ('xataː', 'close.Y', 'v', 7),
#  ('họččọ', 'this.much.Y', 'pron', 4),
#  ('xohoːn', 'poem.Y', 'n', 1),
#  ('delbi', 'very.Y', 'adv', 92),
#  ('xarčị', 'money.Y', 'n', 6),
#  ('kimneːger', 'who.compar.Y', 'pron', 2),
#  ('kas', 'how.many.Y', 'pron', 1),
#  ('muoda', 'strangeness.Y', 'n', 1),
#  ('ọlọktọk', 'life.prop.Y', 'adj', 1),
#  ('bịhaːr', 'explain.Y', 'v', 1),
#  ('behis', 'fifth.Y', 'num', 5),
#  ('buollaγïna', 'dp.Y', 'ptl', 210),
#  ('koːrček', 'whipped.cream.Y', 'n', 1),
#  ('onon', 'therefore.Y', 'conj', 2),
#  ('baγas', 'ptl.Y', 'ptl', 3),
#  ('ühüs', 'third.Y', 'num', 4),
#  ('baččalarga', 'that.much.pl.dat.Y', 'adv', 1),
#  ('kïaχ', 'possibility.Y', 'n', 2),
#  ('huoχ', 'neg.Y', 'ptl', 2),
#  ('hebieskej', 'Soviet.Y', 'adj', 10),
#  ('kïaj', 'be.able.Y', 'v', 1),
#  ('duo', 'q.Y', 'ptl', 16),
#  ('xaːjtar', 'be.delayed.Y', 'v', 4),
#  ('atagasta', 'mistreat.Y', 'v', 2),
#  ('bastakï', 'at.first.Y', 'adv', 3),
#  ('ïarï', 'illness.Y', 'n', 1),
#  ('ọtụtča', 'approx.30.Y', 'num', 1),
#  ('kïajan', 'not.be.able.Y', 'v', 3),
#  ('χajaγas', 'hole.Y', 'n', 2),
#  ('oččoγo', 'then.Y', 'adv', 1),
#  ('bütünnüː', 'entirely.Y', 'n', 19),
#  ('tọjọn', 'lord.Y', 'n', 1),
#  ('onton', 'then.Y', '?', 2),
#  ('čụgas', 'near.Y', 'adj', 3),
#  ('üčügej', 'good.Y', 'adj', 1),
#  ('ụdaγan', 'female.shaman.Y', 'n', 2),
#  ('ikki', 'two.Y', 'num', 3),
#  ('külejdeː', 'go.for.a.walk.Y', 'v', 1),
#  ('anaːn', 'carefully.Y', 'adv', 3),
#  ('teŋŋe', 'on.equal.footing.Y', 'adj', 1),
#  ('tustuː', 'fight.Y', 'n', 1),
#  ('tördüön', 'forty.Y', 'num', 4),
#  ('ọnnọ', 'there.Y', 'pron', 1),
#  ('kuobaχ', 'rabbit.Y', 'n', 1),
#  ('terij', 'organize.Y', 'v', 1),
#  ('ụhụl', 'record.Y', 'v', 2),
#  ('anï_turan', 'in.addition.Y', 'adv', 1),
#  ('interihiergeː', 'be.interested.Y', 'v', 1),
#  ('orox', 'animal.path.Y', 'n', 1),
#  ('kọhọːn', 'poem.Y', 'n', 2),
#  ('bïha', 'throughout.Y', 'postpos', 3),
#  ('tọːraj', 'crossbar.Y', 'n', 3),
#  ('sutuːr', 'commotion??.Y', 'n', 1),
#  ('kïhammat', 'not.care.Y', 'v', 1),
#  ('uopsajïnan', 'in.general.Y', 'adv', 5),
#  ('böγö', 'a.lot.Y', 'quant', 1),
#  ('kịhall', 'take.care.Y', 'v', 1),
#  ('ürdük', 'high.Y', '?', 1),
#  ('tọktọ', 'stop.Y', 'v', 1),
#  ('ịlak', 'crossbar.Y', 'n', 2),
#  ('ebit', 'it.seems.Y', 'ptl', 63),
#  ('menik', 'playful.Y', '?', 1),
#  ('bahïlïk', 'director.Y', 'n', 1),
#  ('mọːdarga', 'be.surprised.Y', 'v', 4),
#  ('maŋnaj', 'first.Y', 'adj', 1),
#  ('arïčča', 'a.bit.Y', 'adv', 1),
#  ('dʒalardaː', 'be.exhausted.Y', 'v', 2),
#  ('araːha', 'maybe.Y', 'adv', 6),
#  ('tohoγo', 'nail.Y', 'n', 7),
#  ('manna', 'here.Y', 'pron', 1),
#  ('astïk', 'very.satisfying.Y', 'adv', 1),
#  ('kïlaːs', 'grade.Y', 'n', 6),
#  ('baγajị', 'very.Y', '?', 23),
#  ('saŋa', 'new.Y', 'adj', 2),
#  ('bụọlụmụna', 'of.course.Y', 'ptl', 1),
#  ('dʒössö', 'also.Y', 'adv', 4),
#  ('kulejdeː', 'go.for.a.walk.Y', 'v', 1),
#  ('Bajanaj', 'spirit.of.hunting.Y', '?', 1),
#  ('tụgụj', 'what.Acc.q.Y', '?', 1),
#  ('balïːha', 'hospital.Y', 'n', 2),
#  ('dʒergeŋneː', 'run.around.lightheartedly.Y', 'v', 1),
#  ('hịŋaːk', 'jaw.Y', 'n', 7),
#  ('bïlïr', 'in.the.past.Y', 'adv', 5),
#  ('meːnik', 'mischievous.Y', 'adj', 2),
#  ('kịahị', 'hobble.Y', 'n', 1),
#  ('ïla', 'since.Y', 'postpos', 8),
#  ('hürdeːk', 'terribly.Y', 'adv', 2),
#  ('idehe', 'slaughter.Y', 'n', 1),
#  ('dʒiktirgeː', 'be.very.surprised.Y', 'v', 1),
#  ('dụọ', 'q.Y', '?', 7),
#  ('kụmaːγï', 'paper.Y', 'n', 2),
#  ('diː', 'ptl.Y', 'ptl', 33),
#  ('ńịlba', 'baby.Y', 'n', 4),
#  ('baraxsan', 'dear.Y', 'ptl', 8),
#  ('ọlọx', 'completely.Y', 'adv', 32),
#  ('tọxtọː', 'stop.Y', 'v', 2),
#  ('tübes', 'find.oneself.Y', 'v', 8),
#  ('die', 'say.Y', 'v', 9),
#  ('turan', 'stand.cvb.Y', 'ptl', 5),
#  ('hataː', 'know.Y', 'v', 4),
#  ('tubes', 'find.oneself.Y', 'v', 1)]

# %%
len(kam_y)
# Out:
# 2

# %%
print(len(get_wdchains(seb)))
len(get_wdchains(kam))
# Out:
# Kejmetinova_AA_headmistress_Yakutsk_310310_LZ.txt
# 49803
# 32778

# %%
3746/49803
# Out:
# 0.07521635242856856

# %%
2280/32778
# Out:
# 0.06955885044847153
