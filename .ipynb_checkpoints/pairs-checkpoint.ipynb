# %% [markdown]
# List of datasets:
#
# ## Everything
#
# Sebjan.pickle, Kamchatka.pickle -- словари формата
#
# `{
#     doc:{    # in a dict, named
#         meta:[meta],    # metainfo at the head
#         text:[
#             {        # sentence (in a list, numbered)
#                 layer:[
#                     morphs    # for mb, ge, ps
#                     ],
#                 layer:''    # e.g. translation
#             }
#         ]
#     }
# }`
#
# ## Converbs
#
# converbs.pickle -- таблица с конвербами + логлайк
#
#
# ## Morphemes
#
# ### Raw
#
# Sebjan_morphemes.pickle, Kamchatka_morphemes.pickle -- raw succession of words like this
#
# ` (0,),    # root
#  ('-B', '-med', 'v'),
#  ('-DEŋ', '-pst.ptc', 'v'),
#  ('-E', '-ep', 'v')
#  (1,)]     # end of the word`
#
# ### Single morphemes
#
# Sebjan_morphemes_only.pickle, Kamchatka_morphemes_only.pickle -- pd of morphemes with counts only
#
# morphemes_count.pickle -- pd of morphemes with counts only by two corp together
#
# total_morphemes.pickle -- таблица с морфемами + логлайк
#
#
#
#  ### Pairs
#
#  Sebjan_pairs_dict.pickle, Kamchatka_pairs_dict.pickle -- dicts of (morph): {morph_after: N}
#
#  pairs.pickle -- pd with pairs and count only
#
#  pairs_by_ll.pickle -- pd with pairs and all the stats

# %%
import os, re, pickle
from pprint import pprint
import numpy as np
import pandas as pd

# %%
pairs = pd.read_pickle('pairs.pickle')
morphs = pd.read_pickle('morpheme_counts.pickle')

# %%
# morphs = pd.read_pickle('total_morphemes.pickle')[['morpheme', 'gloss', 'pos', 's_count', 'k_count']]
# morphs.to_pickle('morpheme_counts.pickle')

# %%
pairs['morpheme'] = pairs['1morpheme']
pairs['gloss'] = pairs['1gloss']
pairs['pos'] = pairs['1pos']
del pairs['1morpheme']
del pairs['1gloss']
del pairs['1pos']
pairs = pd.merge(pairs, morphs, on=['morpheme', 'gloss', 'pos'], suffixes=['_pair', '_one'])

# %%
pairs.head()
# Out:
#   2gloss 2morpheme 2pos  s_count_pair  k_count_pair morpheme   gloss  pos  \
# 0    END       END  END           1.0           NaN      BIt   1pl.Y  ptl
# 1    END       END  END           5.0           NaN      BIt   1pl.Y    v
# 2    END       END  END           NaN           4.0     (R)U  1pl.ex    ?
# 3    END       END  END           NaN           1.0     (R)U  1pl.ex    n
# 4    ptl       tIt    v           NaN           1.0     (R)U  1pl.ex    v
#
#    s_count_one  k_count_one
# 0          1.0          0.0
# 1          5.0          0.0
# 2          0.0          4.0
# 3          0.0          1.0
# 4          0.0        322.0

# %%
# clean up

pairs['s_count_pair'] = pairs['s_count_pair'].fillna(0)
pairs['k_count_pair'] = pairs['k_count_pair'].fillna(0)
pairs = pairs.loc[pairs['s_count_pair'] != 49803]
pairs = pairs.loc[pairs['gloss'] != 0]
pairs = pairs.loc[pairs['gloss'] != '']
pairs = pairs.loc[pairs['gloss'] != '*']
pairs = pairs.loc[pairs['gloss'] != '***']
pairs = pairs.loc[pairs['gloss'] != '******']
pairs = pairs.loc[pairs['gloss'] != 'ep']

# %%
# calculate log-likelihood
# expected = n_of_wds_in_crp_a*(count_in_a+count_in_b)/n_of_wds_in_both
pairs['s_expected'] = pairs['s_count_one']*(pairs['s_count_pair']+pairs['k_count_pair'])/(pairs['s_count_one']+pairs['k_count_one'])
pairs['k_expected'] = pairs['k_count_one']*(pairs['s_count_pair']+pairs['k_count_pair'])/(pairs['s_count_one']+pairs['k_count_one'])
pairs['k_semi_l'] = pairs['k_count_pair']*np.log(pairs['k_count_pair']/pairs['k_expected'])
pairs['s_semi_l'] = pairs['s_count_pair']*np.log(pairs['s_count_pair']/pairs['s_expected'])
pairs['k_semi_l'] = pairs['k_semi_l'].fillna(0)
pairs['s_semi_l'] = pairs['s_semi_l'].fillna(0)
pairs['log_l'] = 2*(pairs['s_semi_l'] + pairs['k_semi_l'])
pairs['ell'] = pairs['log_l']/(82582*np.log(
        pairs['s_expected']*(pairs['s_expected']<pairs['k_expected'])+pairs['k_expected']*(pairs['k_expected']<pairs['s_expected'])
                                     )
                              )
pairs = pairs.sort_values('log_l', ascending=False)

del pairs['k_semi_l']
del pairs['s_semi_l']
del pairs['s_expected']
del pairs['k_expected']

# %%
columns = pairs.columns.tolist()
columns = columns[5:8] + columns[:5] + columns[8:]
pairs = pairs[columns]

# %%
pairs.head(20)
# Out:
#      morpheme   gloss pos       2gloss 2morpheme 2pos  s_count_pair  \
# 2365     R(E)  nonfut   v       1pl.in         p    v         384.0
# 1679     WEːČ     gnr   v       nonfut      R(E)    v          19.0
# 3164        D    prog   v          gnr      WEːČ    v           0.0
# 3285       RI     pst   v  poss.1pl.in      t(I)    v         170.0
# 1681     WEːČ     gnr   v          hab     Gr(E)    v          67.0
# 3287       RI     pst   v  poss.1pl.ex       WUn    v           0.0
# 3154        D    prog   v      sim.cvb     nIkEn    v         112.0
# 3157        D    prog   v     cond.cvb       REk    v         111.0
# 3152        D    prog   v     impf.ptc        RI    v          94.0
# 3148        D    prog   v         inch         L    v           2.0
# 3147        D    prog   v          pst        RI    v          27.0
# 1852        L    inch   v       pf.ptc        čE    v          53.0
# 1694     WEːČ     gnr   v      sim.cvb     nIkEn    v          26.0
# 1676     WEːČ     gnr   v     impf.ptc        RI    v          33.0
# 1974       nE  intent   v     cond.cvb        mI    v          56.0
# 1682     WEːČ     gnr   v         prog         D    v          47.0
# 2590       čE  pf.ptc   v          acc         W    v           6.0
# 3505        Č     res   v          hab     Gr(E)    v          73.0
# 3159        D    prog   v       pf.ptc        čE    v          36.0
# 3516        Č     res   v          gnr      WEːČ    v           4.0
#
#       k_count_pair  s_count_one  k_count_one  s_expected   k_expected  \
# 2365          52.0       2084.0       2956.0  180.282540   255.717460
# 1679        1506.0        335.0       1891.0  229.503594  1295.496406
# 3164         458.0        765.0       1675.0  143.594262   314.405738
# 3285           9.0       1308.0       2712.0   58.241791   120.758209
# 1681           0.0        335.0       1891.0   10.083109    56.916891
# 3287         318.0       1308.0       2712.0  103.468657   214.531343
# 3154           3.0        765.0       1675.0   36.055328    78.944672
# 3157          32.0        765.0       1675.0   44.834016    98.165984
# 3152          21.0        765.0       1675.0   36.055328    78.944672
# 3148         165.0        765.0       1675.0   52.358607   114.641393
# 3147         301.0        765.0       1675.0  102.836066   225.163934
# 1852           2.0        192.0        375.0   18.624339    36.375661
# 1694           0.0        335.0       1891.0    3.912848    22.087152
# 1676           5.0        335.0       1891.0    5.718778    32.281222
# 1974           3.0        108.0        168.0   23.086957    35.913043
# 1682          31.0        335.0       1891.0   11.738544    66.261456
# 2590          24.0       1895.0        211.0   26.994302     3.005698
# 3505           3.0        471.0        467.0   38.162047    37.837953
# 3159           1.0        765.0       1675.0   11.600410    25.399590
# 3516          72.0        471.0        467.0   38.162047    37.837953
#
#            log_l       ell
# 2365  415.043799  0.000968
# 1679  358.820077  0.000799
# 3164  344.585345  0.000840
# 3285  317.468213  0.000946
# 1681  253.773354  0.001330
# 3287  250.326759  0.000653
# 3154  234.270697  0.000791
# 3157  129.517872  0.000412
# 3152  124.531704  0.000421
# 3148  107.105180  0.000328
# 3147  102.535321  0.000268
# 1852   99.254191  0.000411
# 1694   98.479212  0.000874
# 1676   97.031181  0.000674
# 1974   84.346466  0.000325
# 1682   83.306847  0.000410
# 2590   81.675716  0.000899
# 3505   79.490019  0.000265
# 3159   75.068987  0.000371
# 3516   74.598523  0.000249

# %%
# здесь я находила и убирала дубликаты
# pd.concat(g for _, g in morphs.groupby(['morpheme', 'gloss', 'pos']) if len(g) > 1)

# morphs['k_count'][731] = 134
# morphs['k_count'][74] = 233
# morphs['k_count'][494] = 42
# morphs['k_count'][742] = 39
# morphs = morphs.sort_index()
# morphs = morphs.drop(morphs.index[75]).drop(morphs.index[732]).drop(morphs.index[495]).drop(morphs.index[743])

# %%
pd.concat(g for _, g in pairs.groupby(['morpheme', 'gloss', 'pos']))
# Out:
#       morpheme              gloss   pos       2gloss 2morpheme  2pos  \
# 688   (E)hEgEr  as.if.about.to.do     v          END       END   END
# 3630    (E)ldE                soc     v          pst        RI     v
# 3617    (E)ldE                soc     v           nr       ČEk     v
# 3631    (E)ldE                soc     v       1pl.ex      (R)U     v
# 3613    (E)ldE                soc     v          3sg      n(I)     v
# 3624    (E)ldE                soc     v          hab     Gr(E)     v
# 3623    (E)ldE                soc     v      ant.cvb     RIdʒI     v
# 3622    (E)ldE                soc     v       nonfut      R(E)     v
# 3628    (E)ldE                soc     v         prog         D     v
# 3618    (E)ldE                soc     v          fut       DʒI     v
# 3625    (E)ldE                soc     v          END       END   END
# 3627    (E)ldE                soc     v       intent        nE     v
# 3620    (E)ldE                soc     v       pf.ptc        čE     v
# 3614    (E)ldE                soc     v          gnr      WEːČ     v
# 3615    (E)ldE                soc     v      sim.cvb     nIkEn     v
# 3626    (E)ldE                soc     v     cond.cvb        mI     v
# 3616    (E)ldE                soc     v      pst.ptc       DEŋ     v
# 3619    (E)ldE                soc     v         conn         j     v
# 3629    (E)ldE                soc     v   imp.1pl.in       GEr     v
# 3612    (E)ldE                soc     v          3pl         r     v
# 3621    (E)ldE                soc     v          rec       mEČ     v
# 475     (E)pkI               advr     v          END       END   END
# 325     (E)rEp               adjr     ?          END       END   END
# 324     (E)rEp               adjr     ?      prfl.sg         J     ?
# 329     (E)rEp               adjr   adj         adjr      pčVn   adj
# 327     (E)rEp               adjr   adj            q        GU   adj
# 328     (E)rEp               adjr   adj          dat        DU   adj
# 326     (E)rEp               adjr   adj          abl    DUk(U)   adj
# 339     (E)rEp               adjr   adv          acc         W   adv
# 341     (E)rEp               adjr   adv      all.loc       klE   adv
# ...        ...                ...   ...          ...       ...   ...
# 3057        ŋI          pred.poss     ?          ptl        DE     ?
# 3067        ŋI          pred.poss     n          ptl       kkE     n
# 3062        ŋI          pred.poss     n          acc         W     n
# 3061        ŋI          pred.poss     n          END       END   END
# 3064        ŋI          pred.poss     n  poss.1pl.ex       WUn     n
# 3065        ŋI          pred.poss     n     poss.3sg      n(I)     n
# 3063        ŋI          pred.poss     n          ptl      mEjE     n
# 3066        ŋI          pred.poss     n         emph        kE     n
# 3060        ŋI          pred.poss     n          ptl        DE     n
# 3068        ŋI          pred.poss   num     poss.3pl       tEn   num
# 3069        ŋI          pred.poss   num     poss.3sg      n(I)   num
# 3071        ŋI          pred.poss  pron     poss.3sg      n(I)  pron
# 3076        ŋI          pred.poss  pron          ptl        DE  pron
# 3074        ŋI          pred.poss  pron        restr   t(E)kEn  pron
# 3075        ŋI          pred.poss  pron        indef   (W)UttE  pron
# 3077        ŋI          pred.poss  pron  ins.prfl.sg       DʒI  pron
# 3072        ŋI          pred.poss  pron          END       END   END
# 3070        ŋI          pred.poss  pron     poss.3pl       tEn  pron
# 3073        ŋI          pred.poss  pron           pl         L  pron
# 135        ŋaː                 ??   adj          aug      mkEr   adj
# 2508       ŋkE                 nr     n          END       END   END
# 2509       ŋkE                 nr     v          acc         W     v
# 2514       ŋkE         obligation     v          END       END   END
# 1787       ŋsI           impf.cvb     v     poss.3pl       tEn     v
# 1786       ŋsI           impf.cvb     v     poss.1sg         W     v
# 1785       ŋsI           impf.cvb     v  poss.1pl.in      t(I)     v
# 1784       ŋsI           impf.cvb     v      prfl.pl       WUr     v
# 1783       ŋsI           impf.cvb     v          acc         W     v
# 1782       ŋsI           impf.cvb     v     poss.3sg      n(I)     v
# 1781       ŋsI           impf.cvb     v      prfl.sg         J     v
#
#       s_count_pair  k_count_pair  s_count_one  k_count_one  s_expected  \
# 688            1.0           0.0          1.0          0.0    1.000000
# 3630           4.0           4.0         46.0         12.0    6.344828
# 3617           7.0           0.0         46.0         12.0    5.551724
# 3631           0.0           1.0         46.0         12.0    0.793103
# 3613           1.0           2.0         46.0         12.0    2.379310
# 3624           5.0           0.0         46.0         12.0    3.965517
# 3623           3.0           0.0         46.0         12.0    2.379310
# 3622           3.0           0.0         46.0         12.0    2.379310
# 3628           2.0           0.0         46.0         12.0    1.586207
# 3618           2.0           0.0         46.0         12.0    1.586207
# 3625           2.0           0.0         46.0         12.0    1.586207
# 3627           2.0           0.0         46.0         12.0    1.586207
# 3620           1.0           1.0         46.0         12.0    1.586207
# 3614           1.0           1.0         46.0         12.0    1.586207
# 3615           1.0           0.0         46.0         12.0    0.793103
# 3626           1.0           0.0         46.0         12.0    0.793103
# 3616           1.0           0.0         46.0         12.0    0.793103
# 3619           1.0           0.0         46.0         12.0    0.793103
# 3629           1.0           0.0         46.0         12.0    0.793103
# 3612           2.0           1.0         46.0         12.0    2.379310
# 3621           6.0           2.0         46.0         12.0    6.344828
# 475            1.0           0.0          1.0          0.0    1.000000
# 325            3.0           0.0          4.0          0.0    3.000000
# 324            1.0           0.0          4.0          0.0    1.000000
# 329            0.0           1.0          5.0          2.0    0.714286
# 327            1.0           0.0          5.0          2.0    0.714286
# 328            1.0           0.0          5.0          2.0    0.714286
# 326            3.0           1.0          5.0          2.0    2.857143
# 339            1.0           2.0        116.0          9.0    2.784000
# 341            0.0           1.0        116.0          9.0    0.928000
# ...            ...           ...          ...          ...         ...
# 3057           2.0           2.0         13.0         15.0    1.857143
# 3067           0.0           2.0         16.0         21.0    0.864865
# 3062           0.0           2.0         16.0         21.0    0.864865
# 3061          14.0          11.0         16.0         21.0   10.810811
# 3064           0.0           1.0         16.0         21.0    0.432432
# 3065           0.0           1.0         16.0         21.0    0.432432
# 3063           0.0           1.0         16.0         21.0    0.432432
# 3066           0.0           1.0         16.0         21.0    0.432432
# 3060           2.0           2.0         16.0         21.0    1.729730
# 3068           1.0           0.0          1.0          1.0    0.500000
# 3069           0.0           1.0          1.0          1.0    0.500000
# 3071           4.0           0.0         15.0         25.0    1.500000
# 3076           0.0           1.0         15.0         25.0    0.375000
# 3074           0.0           1.0         15.0         25.0    0.375000
# 3075           0.0           1.0         15.0         25.0    0.375000
# 3077           0.0           1.0         15.0         25.0    0.375000
# 3072           8.0          18.0         15.0         25.0    9.750000
# 3070           2.0           2.0         15.0         25.0    1.500000
# 3073           1.0           1.0         15.0         25.0    0.750000
# 135            0.0           1.0          0.0          1.0    0.000000
# 2508           0.0           1.0          0.0          1.0    0.000000
# 2509           2.0           0.0          2.0          0.0    2.000000
# 2514           3.0           0.0          3.0          0.0    3.000000
# 1787           2.0           0.0         44.0          0.0    2.000000
# 1786           2.0           0.0         44.0          0.0    2.000000
# 1785           4.0           0.0         44.0          0.0    4.000000
# 1784           8.0           0.0         44.0          0.0    8.000000
# 1783           1.0           0.0         44.0          0.0    1.000000
# 1782           5.0           0.0         44.0          0.0    5.000000
# 1781          22.0           0.0         44.0          0.0   22.000000
#
#       k_expected     log_l           ell
# 688     0.000000  0.000000 -0.000000e+00
# 3630    1.655172  3.368349  8.094366e-05
# 3617    1.448276  3.245223  1.061008e-04
# 3631    0.206897  3.151073 -2.421835e-05
# 3613    0.620690  2.946664 -7.481625e-05
# 3624    1.034483  2.318016  8.279641e-04
# 3623    0.620690  1.390810 -3.531287e-05
# 3622    0.620690  1.390810 -3.531287e-05
# 3628    0.413793  0.927206 -1.272421e-05
# 3618    0.413793  0.927206 -1.272421e-05
# 3625    0.413793  0.927206 -1.272421e-05
# 3627    0.413793  0.927206 -1.272421e-05
# 3620    0.413793  0.842087 -1.155611e-05
# 3614    0.413793  0.842087 -1.155611e-05
# 3615    0.206897  0.463603 -3.563138e-06
# 3626    0.206897  0.463603 -3.563138e-06
# 3616    0.206897  0.463603 -3.563138e-06
# 3619    0.206897  0.463603 -3.563138e-06
# 3629    0.206897  0.463603 -3.563138e-06
# 3612    0.620690  0.259194 -6.580980e-06
# 3621    1.655172  0.086402  2.076309e-06
# 475     0.000000  0.000000 -0.000000e+00
# 325     0.000000  0.000000 -0.000000e+00
# 324     0.000000  0.000000 -0.000000e+00
# 329     0.285714  2.505526 -2.421835e-05
# 327     0.285714  0.672944 -6.504665e-06
# 328     0.285714  0.672944 -6.504665e-06
# 326     1.142857  0.025678  2.328605e-06
# 339     0.216000  6.854719 -5.416395e-05
# 341     0.072000  5.262178 -2.421835e-05
# ...          ...       ...           ...
# 3057    2.142857  0.020460  4.002309e-07
# 3067    1.135135  2.265582 -1.889651e-04
# 3062    1.135135  2.265582 -1.889651e-04
# 3061   14.189189  1.637428  8.329138e-06
# 3064    0.567568  1.132791 -1.636250e-05
# 3065    0.567568  1.132791 -1.636250e-05
# 3063    0.567568  1.132791 -1.636250e-05
# 3066    0.567568  1.132791 -1.636250e-05
# 3060    2.270270  0.073721  1.629124e-06
# 3068    0.500000  1.386294 -0.000000e+00
# 3069    0.500000  1.386294 -0.000000e+00
# 3071    2.500000  7.846634  2.343390e-04
# 3076    0.625000  0.940007 -1.160519e-05
# 3074    0.625000  0.940007 -1.160519e-05
# 3075    0.625000  0.940007 -1.160519e-05
# 3077    0.625000  0.940007 -1.160519e-05
# 3072   16.250000  0.516827  2.748182e-06
# 3070    2.500000  0.258154  7.709747e-06
# 3073    1.250000  0.129077 -5.433139e-06
# 135     1.000000  0.000000 -0.000000e+00
# 2508    1.000000  0.000000 -0.000000e+00
# 2509    0.000000  0.000000 -0.000000e+00
# 2514    0.000000  0.000000 -0.000000e+00
# 1787    0.000000  0.000000 -0.000000e+00
# 1786    0.000000  0.000000 -0.000000e+00
# 1785    0.000000  0.000000 -0.000000e+00
# 1784    0.000000  0.000000 -0.000000e+00
# 1783    0.000000  0.000000 -0.000000e+00
# 1782    0.000000  0.000000 -0.000000e+00
# 1781    0.000000  0.000000 -0.000000e+00
#
# [3829 rows x 14 columns]
